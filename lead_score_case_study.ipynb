# %%
import pandas as pd                                         # for analyzing data sets
import numpy as np
import warnings                                             # for ignoring warings
import sklearn as sk                                        # for data analysis
import matplotlib.pyplot as plt                             
import seaborn as sb                                        # for drawing visual graps of statistical data
import statsmodels.api as ap
from sklearn.preprocessing import MinMaxScaler as scaler    # for scaling of the model
from sklearn.model_selection import train_test_split        
from statsmodels.api import regression as rg                # handling all the statistical data
from statsmodels.api import add_constant
warnings.filterwarnings("ignore")

# %%
app = pd.read_csv("Leads.csv")
app.head(5)
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
# FEATURE ENGEENERING

app.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# ...

# %%
app.columns
# Out:
# Index(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
#        'Do Not Email', 'Do Not Call', 'Converted', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Country', 'Specialization', 'How did you hear about X Education',
#        'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'Lead Profile', 'City', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score',
#        'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
# ...

# %%
x=pd.DataFrame((app.isnull().sum()/app.shape[0])*100).reset_index().to_dict("record")
for item in x:
    print(item)
# Out:
# {'index': 'Prospect ID', 0: 0.0}
# {'index': 'Lead Number', 0: 0.0}
# {'index': 'Lead Origin', 0: 0.0}
# {'index': 'Lead Source', 0: 0.38961038961038963}
# {'index': 'Do Not Email', 0: 0.0}
# {'index': 'Do Not Call', 0: 0.0}
# {'index': 'Converted', 0: 0.0}
# {'index': 'TotalVisits', 0: 1.4826839826839828}
# {'index': 'Total Time Spent on Website', 0: 0.0}
# {'index': 'Page Views Per Visit', 0: 1.4826839826839828}
# {'index': 'Last Activity', 0: 1.1147186147186148}
# {'index': 'Country', 0: 26.634199134199132}
# {'index': 'Specialization', 0: 15.562770562770561}
# {'index': 'How did you hear about X Education', 0: 23.885281385281385}
# {'index': 'What is your current occupation', 0: 29.11255411255411}
# {'index': 'What matters most to you in choosing a course', 0: 29.318181818181817}
# {'index': 'Search', 0: 0.0}
# {'index': 'Magazine', 0: 0.0}
# {'index': 'Newspaper Article', 0: 0.0}
# {'index': 'X Education Forums', 0: 0.0}
# {'index': 'Newspaper', 0: 0.0}
# ...

# %%
app.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
(app.isna().sum()/app.shape[0])*100
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Do Not Email                                      0.000000
# Do Not Call                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       1.482684
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Country                                          26.634199
# Specialization                                   15.562771
# How did you hear about X Education               23.885281
# What is your current occupation                  29.112554
# What matters most to you in choosing a course    29.318182
# ...

# %%
app.replace('Select',np.nan,inplace=True)

# %%
for item in list(app.columns):
    if app[app[item]=='Select'].shape[0]>0:
        print(item)

# %%
app["Country"].describe()
# Out:
# count      6779
# unique       38
# top       India
# freq       6492
# Name: Country, dtype: object

# %%
(app.City.isna().sum()/app.shape[0])*100
# Out:
# 39.70779220779221

# %%
app["What is your current occupation"].describe()
# Out:
# count           6550
# unique             6
# top       Unemployed
# freq            5600
# Name: What is your current occupation, dtype: object

# %%
app["What matters most to you in choosing a course"].describe()
# Out:
# count                        6531
# unique                          3
# top       Better Career Prospects
# freq                         6528
# Name: What matters most to you in choosing a course, dtype: object

# %%
app["Specialization"].describe()
# Out:
# count                   5860
# unique                    18
# top       Finance Management
# freq                     976
# Name: Specialization, dtype: object

# %%
app["City"].describe()
# Out:
# count       5571
# unique         6
# top       Mumbai
# freq        3222
# Name: City, dtype: object

# %%
col=["Asymmetrique Profile Score","Asymmetrique Activity Index","Asymmetrique Profile Index","Lead Quality","Asymmetrique Activity Score"]
app.drop(columns=col,inplace=True)
col
# Out:
# ['Asymmetrique Profile Score',
#  'Asymmetrique Activity Index',
#  'Asymmetrique Profile Index',
#  'Lead Quality',
#  'Asymmetrique Activity Score']

# %%
app.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
# dropping the data having more then 70% NaN data
per=70
min_cnt=int((((100-per)/100)*(app.shape[1])+1))
app.dropna(axis=0,how='any',thresh=min_cnt,inplace=True,subset=None)

# %%
app
# Out:
#                                Prospect ID  Lead Number  \
# 0     7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737
# 1     2a272436-5132-4136-86fa-dcc88c88f482       660728
# 2     8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727
# 3     0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719
# 4     3256f628-e534-4826-9d63-4a8b88782852       660681
# ...                                    ...          ...
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9       579564
# 9236  82a7005b-7196-4d56-95ce-a79f937a158d       579546
# 9237  aac550fe-a586-452d-8d3c-f1b62c94e02c       579545
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9       579538
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff       579533
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 0                         API      Olark Chat           No          No
# 1                         API  Organic Search           No          No
# 2     Landing Page Submission  Direct Traffic           No          No
# ...

# %%
app["Do Not Call"].value_counts()
# Out:
# No     9238
# Yes       2
# Name: Do Not Call, dtype: int64

# %%
app.drop(columns="Do Not Call",inplace=True)

# %%
app["Do Not Email"].value_counts()
# Out:
# No     8506
# Yes     734
# Name: Do Not Email, dtype: int64

# %%
app.drop(columns="Do Not Email",inplace=True)
app.drop(columns="Tags",inplace=True)
app.drop(columns="City",inplace=True)

# %%
app["TotalVisits"].fillna(3.000000,inplace=True)         # filling all the NULL value of TotalVisits column with median 3
app["Page Views Per Visit"].fillna(2.00000,inplace=True)
app["How did you hear about X Education"].fillna('Others',inplace=True)
app["What is your current occupation"].fillna('Unemployement',inplace=True)
app["What matters most to you in choosing a course"].fillna('Better Career Prospects',inplace=True)
app["Country"].fillna('India',inplace=True)
# app["Specialization"].fillna('Finance Management',inplace=True)

# %%
app[(app.Specialization=='Finance Management')]
# Out:
#                                Prospect ID  Lead Number  \
# 9     af465dfc-7204-4130-9e05-33231863c4b5       660616
# 23    ecbc6e69-29a9-44bf-804a-13079ef301bc       660461
# 26    c494aca4-8c8e-4081-9784-41eb6346015e       660432
# 37    e60a54bc-0816-430e-a99a-019a8b5a27e5       660267
# 43    abc432ac-7393-4312-b49f-c43702397416       660203
# ...                                    ...          ...
# 9200  3d227b46-538e-439a-b55d-86bdd9697dfa       579890
# 9201  906e989a-049c-4642-8166-2d5c01094f49       579889
# 9202  e2549e78-3f13-4283-9cb2-cbb65b893662       579885
# 9220  679ab5f9-0f85-4f16-a903-821ecd82e731       579769
# 9228  40d3b3cf-d939-49ff-bea5-60e8d4025104       579717
#
#                   Lead Origin     Lead Source  Converted  TotalVisits  \
# 9                         API          Google          0          4.0
# 23    Landing Page Submission          Google          0          4.0
# 26    Landing Page Submission  Organic Search          1          4.0
# ...

# %%
app[(app.Specialization=='Finance Management')]["Lead Source"].value_counts()
# Out:
# Direct Traffic      384
# Google              371
# Organic Search       93
# Reference            79
# Olark Chat           36
# Facebook              4
# Referral Sites        3
# Welingak Website      2
# Click2call            1
# Name: Lead Source, dtype: int64

# %%
app["Lead Source"].value_counts()
# Out:
# Google               2868
# Direct Traffic       2543
# Olark Chat           1755
# Organic Search       1154
# Reference             534
# Welingak Website      142
# Referral Sites        125
# Facebook               55
# bing                    6
# google                  5
# Click2call              4
# Press_Release           2
# Social Media            2
# Live Chat               2
# youtubechannel          1
# testone                 1
# Pay per Click Ads       1
# welearnblog_Home        1
# WeLearn                 1
# blog                    1
# NC_EDM                  1
# Name: Lead Source, dtype: int64

# %%
app[(app.Specialization=='Finance Management')]["Lead Source"].value_counts()/app["Lead Source"].value_counts()
# Out:
# Click2call           0.250000
# Direct Traffic       0.151003
# Facebook             0.072727
# Google               0.129358
# Live Chat                 NaN
# NC_EDM                    NaN
# Olark Chat           0.020513
# Organic Search       0.080589
# Pay per Click Ads         NaN
# Press_Release             NaN
# Reference            0.147940
# Referral Sites       0.024000
# Social Media              NaN
# WeLearn                   NaN
# Welingak Website     0.014085
# bing                      NaN
# blog                      NaN
# google                    NaN
# testone                   NaN
# welearnblog_Home          NaN
# youtubechannel            NaN
# Name: Lead Source, dtype: float64

# %%
(app.isna().sum()/app.shape[0])*100
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Converted                                         0.000000
# TotalVisits                                       0.000000
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              0.000000
# Last Activity                                     1.114719
# Country                                           0.000000
# Specialization                                   36.580087
# How did you hear about X Education                0.000000
# What is your current occupation                   0.000000
# What matters most to you in choosing a course     0.000000
# Search                                            0.000000
# Magazine                                          0.000000
# ...

# %%
app.drop(columns=["Lead Profile","Last Activity"],axis=1,inplace=True)

# %%
(app.isna().sum()/app.shape[0])*100
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.389610
# Converted                                         0.000000
# TotalVisits                                       0.000000
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              0.000000
# Country                                           0.000000
# Specialization                                   36.580087
# How did you hear about X Education                0.000000
# What is your current occupation                   0.000000
# What matters most to you in choosing a course     0.000000
# Search                                            0.000000
# Magazine                                          0.000000
# Newspaper Article                                 0.000000
# ...

# %%
app["Lead Source"].value_counts(normalize=True)   # checking for The Lead Values
# Out:
# Google               0.311604
# Direct Traffic       0.276293
# Olark Chat           0.190678
# Organic Search       0.125380
# Reference            0.058018
# Welingak Website     0.015428
# Referral Sites       0.013581
# Facebook             0.005976
# bing                 0.000652
# google               0.000543
# Click2call           0.000435
# Press_Release        0.000217
# Social Media         0.000217
# Live Chat            0.000217
# youtubechannel       0.000109
# testone              0.000109
# Pay per Click Ads    0.000109
# welearnblog_Home     0.000109
# WeLearn              0.000109
# blog                 0.000109
# NC_EDM               0.000109
# Name: Lead Source, dtype: float64

# %%
app=app[~app["Lead Source"].isnull()]  # dropping the leads that are NULL

# %%
(app.isna().sum()/app.shape[0])*100
# Out:
# Prospect ID                                       0.000000
# Lead Number                                       0.000000
# Lead Origin                                       0.000000
# Lead Source                                       0.000000
# Converted                                         0.000000
# TotalVisits                                       0.000000
# Total Time Spent on Website                       0.000000
# Page Views Per Visit                              0.000000
# Country                                           0.000000
# Specialization                                   36.418948
# How did you hear about X Education                0.000000
# What is your current occupation                   0.000000
# What matters most to you in choosing a course     0.000000
# Search                                            0.000000
# Magazine                                          0.000000
# Newspaper Article                                 0.000000
# ...

# %%
app.shape
# Out:
# (9204, 26)

# %%
x
# Out:
# [{'index': 'Prospect ID', 0: 0.0},
#  {'index': 'Lead Number', 0: 0.0},
#  {'index': 'Lead Origin', 0: 0.0},
#  {'index': 'Lead Source', 0: 0.38961038961038963},
#  {'index': 'Do Not Email', 0: 0.0},
#  {'index': 'Do Not Call', 0: 0.0},
#  {'index': 'Converted', 0: 0.0},
#  {'index': 'TotalVisits', 0: 1.4826839826839828},
#  {'index': 'Total Time Spent on Website', 0: 0.0},
#  {'index': 'Page Views Per Visit', 0: 1.4826839826839828},
#  {'index': 'Last Activity', 0: 1.1147186147186148},
#  {'index': 'Country', 0: 26.634199134199132},
#  {'index': 'Specialization', 0: 15.562770562770561},
#  {'index': 'How did you hear about X Education', 0: 23.885281385281385},
#  {'index': 'What is your current occupation', 0: 29.11255411255411},
#  {'index': 'What matters most to you in choosing a course',
#   0: 29.318181818181817},
#  {'index': 'Search', 0: 0.0},
#  {'index': 'Magazine', 0: 0.0},
#  {'index': 'Newspaper Article', 0: 0.0},
#  {'index': 'X Education Forums', 0: 0.0},
# ...
